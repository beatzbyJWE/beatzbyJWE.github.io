# %% [markdown]
# # Extracting and Comparing Year Transit Facility Rebuilt From Notes

# %% [markdown]
# ## Loading in Data

# %% [markdown]
# In this exercise I will need the regex (re) package, pandas, and natural language toolkit.

# %%
import re
import pandas as pd
import nltk

pd.set_option('display.max_rows',200)
pd.set_option('display.max_colwidth',-1)
# Out:
# /Users/Joe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   import sys

# %% [markdown]
# I am pulling in a published dataset that my team would like to work with. Each record holds data on a single transit agency facility, reported as of 2019.

# %%
response='https://www.transit.dot.gov/sites/fta.dot.gov/files/2020-10/2019%20Facility%20Inventory.xlsx'
response
df=pd.read_excel(response)

# %% [markdown]
# There is a column for Year Built, as well as the date of the last condition assessment of the given facility, and any notes that the reporting transit agency felt were relevant to include. I only care about these particular records (along with the name of the agency) and I only care about records that have notes provided.

# %%
al=df[['Agency Name','Year Built','Condition Assessment','Condition Assessment Date','Notes']]
Notes_only=al[al.Notes.notnull()] #filtering out all non-null notes
Notes_only
# Out:
#                                    Agency Name  Year Built  \
# 0      King County Department of Metro Transit        2017
# 5      King County Department of Metro Transit        2011
# 9      King County Department of Metro Transit        1980
# 12     King County Department of Metro Transit        2014
# 13     King County Department of Metro Transit        2014
# ...                                        ...         ...
# 13305     County of Hawaii Mass Transit Agency        2018
# 13306                          Humboldt County        2016
# 13308              Pahrump Senior Center, Inc.        1960
# 13315                       City of El Segundo        2008
# 13317                               Mt Clemens        2017
#
#        Condition Assessment Condition Assessment Date  \
# 0                       NaN                       NaT
# 5                       3.0                2015-01-01
# 9                       3.0                2015-01-01
# 12                      3.0                2015-01-01
# 13                      3.0                2015-01-01
# ...                     ...                       ...
# 13305                   5.0                2018-06-30
# 13306                   5.0                2017-02-10
# 13308                   4.0                2018-09-30
# 13315                   5.0                2018-10-01
# 13317                   5.0                2018-03-28
#
#                                                    Notes
# 0      Administrative offices, call & dispatch center...
# 5                                    Operations Building
# 9                                       Hostler building
# 12          Maintenance emergency spill response storage
# 13                        Maintenance tire chain storage
# ...                                                  ...
# 13305  Facility includes a 110'x150' Maintenance Area...
# 13306  Senior center, Admin, Passenger parking, and v...
# 13308  Pahrump Senior Center, parking, passenger load...
# 13315  This facility was built by El Segundo, the lan...
# 13317                BUS GARAGE/DISPATCH/SUPVSR OFFICE\n
#
# [6474 rows x 5 columns]

# %% [markdown]
# ## Using String Contains & Pattern to Extract Year

# %% [markdown]
# Now I will use str.contains to find a four digit year, which can be in either the 1900s or the 2000s. The first command below will limit the Notes only table to Notes_year, a new dataframe with notes containing at least one four digit value.

# %%
Notes_year=Notes_only[Notes_only['Notes'].str.contains('1[0-9]{3}','20[0-9]{2}')] #497 have rows that are probably years
Notes_year['Notes']
# Out:
# 166      1212 Sharp is a administrative offices. Major ...
# 425      Original agreement between IT and WSDOT began ...
# 478                                 47.178324, -122.677895
# 942                   Permanent Admin Facility  built 1898
# 945                Tower - Unoccupied/Abandoned Built 1875
#                                ...
# 13038    combination of admin space (2963 sf) and maint...
# 13143    Facility type is hybrid Administrative and Mai...
# 13144    Facility type is hybrid Administrative and Mai...
# 13145    Facility type is hybrid Administrative and Mai...
# 13296    Lassen Rural Bus Office and Maintenance Bay.  ...
# Name: Notes, Length: 200, dtype: object

# %%
with pd.option_context('display.max_colwidth', -1): display(Notes_year) #https://stackoverflow.com/questions/25351968/how-to-display-full-non-truncated-dataframe-information-in-html-when-convertin
# Out:
#                    Agency Name  Year Built Condition Assessment Date  \
# 166  Spokane Transit Authority        2015                2017-04-28
#
#                                                  Notes
# 166  1212 Sharp is a administrative offices. Major ...

# %% [markdown]
# ## Extracting Condition Assessment from Notes

# %% [markdown]
# Now I will try to extract condition assessment, a single value, from the Notes section.

# %%
pattern2='Condition'
Notes_CA=Notes_only[Notes_only['Notes'].str.contains('assessment')] #497 have rows that are probably years
Notes_CA
# Out:
#                                                                 Agency Name  \
# 0      King County Department of Metro Transit
# 421    Intercity Transit
# 425    Intercity Transit
# 2714   Metro-North Commuter Railroad Company, dba: MTA Metro-North Railroad
# 5700   City of Winston Salem
# 6263   Alternativa de Transporte Integrado -ATI
# 6264   Alternativa de Transporte Integrado -ATI
# 6265   Alternativa de Transporte Integrado -ATI
# 6266   Alternativa de Transporte Integrado -ATI
# 6267   Alternativa de Transporte Integrado -ATI
# 6274   Alternativa de Transporte Integrado -ATI
# 6275   Alternativa de Transporte Integrado -ATI
# 6698   Southwest Ohio Regional Transit Authority
# 6943   Metro Transit
# 6944   Metro Transit
# 6945   Metro Transit
# 6946   Metro Transit
# 6947   Metro Transit
# 6948   Metro Transit
# 6949   Metro Transit
# 6950   Metro Transit
# 6951   Metro Transit
# 6952   Metro Transit
# 6953   Metro Transit
# 6954   Metro Transit
# 6956   Metro Transit
# 6957   Metro Transit
# 6958   Metro Transit
# 6959   Metro Transit
# 6960   Metro Transit
# 6961   Metro Transit
# 6962   Metro Transit
# 6963   Metro Transit
# 6964   Metro Transit
# 6965   Metro Transit
# 6966   Metro Transit
# 6967   Metro Transit
# 6968   Metro Transit
# 6969   Metro Transit
# 6970   Metro Transit
# 6971   Metro Transit
# 6972   Metro Transit
# 6973   Metro Transit
# 6974   Metro Transit
# 6975   Metro Transit
# 6976   Metro Transit
# 6977   Metro Transit
# 6978   Metro Transit
# 6979   Metro Transit
# 6980   Metro Transit
# 6981   Metro Transit
# 6982   Metro Transit
# 6983   Metro Transit
# 6984   Metro Transit
# 6985   Metro Transit
# 6986   Metro Transit
# 6987   Metro Transit
# 6988   Metro Transit
# 6989   Metro Transit
# 6990   Metro Transit
# 6991   Metro Transit
# 6992   Metro Transit
# 6993   Metro Transit
# 6994   Metro Transit
# 6995   Metro Transit
# 6996   Metro Transit
# 6998   Metro Transit
# 7000   Metro Transit
# 7001   Metro Transit
# 7004   Metro Transit
# 7005   Metro Transit
# 7006   Metro Transit
# 7007   Metro Transit
# 7008   Metro Transit
# 7009   Metro Transit
# 7010   Metro Transit
# 7011   Metro Transit
# 7012   Metro Transit
# 7013   Metro Transit
# 7014   Metro Transit
# 7015   Metro Transit
# 7016   Metro Transit
# 7017   Metro Transit
# 7018   Metro Transit
# 7019   Metro Transit
# 7020   Metro Transit
# 7021   Metro Transit
# 7022   Metro Transit
# 7023   Metro Transit
# 7024   Metro Transit
# 7025   Metro Transit
# 7026   Metro Transit
# 7027   Metro Transit
# 7028   Metro Transit
# 7029   Metro Transit
# 7030   Metro Transit
# 7031   Metro Transit
# 7032   Metro Transit
# 7033   Metro Transit
# 7034   Metro Transit
# 7036   Metro Transit
# 7037   Metro Transit
# 7038   Metro Transit
# 7049   Metro Transit
# 7052   Metro Transit
# 7053   Metro Transit
# 7065   Metro Transit
# 7066   Metro Transit
# 7067   Metro Transit
# 7068   Metro Transit
# 7069   Metro Transit
# 7070   Metro Transit
# 7071   Metro Transit
# 7072   Metro Transit
# 7073   Metro Transit
# 7074   Metro Transit
# 8908   Metropolitan Council
# 8913   Metropolitan Council
# 8914   Metropolitan Council
# 8915   Metropolitan Council
# 8916   Metropolitan Council
# 8917   Metropolitan Council
# 8922   Metropolitan Council
# 9693   North Central Regional Transit District
# 9694   North Central Regional Transit District
# 9854   City of Wichita
# 9856   City of Wichita
# 10461  Santa Cruz Metropolitan Transit District
# 10462  Santa Cruz Metropolitan Transit District
# 10468  Santa Cruz Metropolitan Transit District
# 10694  City and County of San Francisco
# 10695  City and County of San Francisco
# 10696  City and County of San Francisco
# 10712  City and County of San Francisco
# 10713  City and County of San Francisco
# 10731  City and County of San Francisco
# 10734  City and County of San Francisco
# 10735  City and County of San Francisco
# 10736  City and County of San Francisco
# 10737  City and County of San Francisco
# 12334  Yamhill County
# 12549  Calhoun County Senior Citizens Association, Inc.
# 12842  Community Action Agency of South Central Michigan
# 12935  Black River Area Development, Inc. (BRAD Public Transit)
#
#        Year Built  Condition Assessment Condition Assessment Date  \
# 0      2017       NaN                   NaT
# 421    1995        3.0                  2020-02-14
# 425    1983        4.0                  2020-02-14
# 2714   2013        3.0                  2018-08-01
# 5700   1996        2.0                  2018-06-30
# 6263   2003        3.0                  2018-08-25
# 6264   2003        3.0                  2018-08-02
# 6265   2003        4.0                  2018-07-23
# 6266   2002        4.0                  2018-08-16
# 6267   2002        4.0                  2018-08-23
# 6274   2003        3.0                  2018-08-23
# 6275   2003        3.0                  2018-08-02
# 6698   1998        4.0                  2018-08-31
# 6943   2007        4.0                  2018-06-14
# 6944   2007        4.0                  2019-04-22
# 6945   1993        4.0                  2019-03-11
# 6946   2009        4.0                  2018-03-30
# 6947   2009        4.0                  2018-04-03
# 6948   1993        4.0                  2019-03-11
# 6949   2009        4.0                  2019-03-11
# 6950   2010        4.0                  2019-03-11
# 6951   2010        4.0                  2019-03-11
# 6952   2010        4.0                  2019-04-22
# 6953   2010        3.0                  2019-04-22
# 6954   2011        4.0                  2018-06-11
# 6956   2013        3.0                  2019-03-12
# 6957   2010        4.0                  2018-07-19
# 6958   2010        4.0                  2018-06-14
# 6959   2010        4.0                  2018-07-19
# 6960   2013        4.0                  2019-03-12
# 6961   2013        4.0                  2019-03-12
# 6962   2013        4.0                  2019-03-12
# 6963   2013        4.0                  2019-03-12
# 6964   2013        4.0                  2019-03-12
# 6965   2010        4.0                  2018-07-19
# 6966   2005        4.0                  2018-03-28
# 6967   2013        4.0                  2019-03-12
# 6968   2013        4.0                  2019-03-12
# 6969   2004        4.0                  2018-03-29
# 6970   2014        4.0                  2019-03-12
# 6971   2013        4.0                  2019-03-12
# 6972   2013        4.0                  2019-03-12
# 6973   2013        4.0                  2019-03-12
# 6974   2013        4.0                  2019-03-12
# 6975   2013        4.0                  2019-03-12
# 6976   2005        4.0                  2018-07-19
# 6977   2013        4.0                  2019-03-12
# 6978   2013        4.0                  2019-03-12
# 6979   2013        4.0                  2019-03-12
# 6980   2013        4.0                  2019-03-12
# 6981   1962        3.0                  2018-03-31
# 6982   2010        4.0                  2018-07-19
# 6983   2010        4.0                  2018-07-19
# 6984   2010        4.0                  2018-07-19
# 6985   2010        4.0                  2018-07-19
# 6986   2010        4.0                  2018-07-19
# 6987   2005        4.0                  2018-03-29
# 6988   2005        4.0                  2018-03-28
# 6989   2005        4.0                  2018-03-29
# 6990   2005        4.0                  2018-03-29
# 6991   2005        4.0                  2018-03-28
# 6992   2012        3.0                  2018-11-16
# 6993   2014        4.0                  2019-03-11
# 6994   2011        4.0                  2019-04-22
# 6995   2004        4.0                  2019-04-22
# 6996   2009       NaN                   NaT
# 6998   2003        3.0                  2018-04-04
# 7000   2003        3.0                  2018-03-31
# 7001   1977        3.0                  2018-03-29
# 7004   2004       NaN                   NaT
# 7005   2007       NaN                   NaT
# 7006   2012        4.0                  2018-06-14
# 7007   1993        3.0                  2019-04-22
# 7008   2004        4.0                  2019-04-24
# 7009   2002        3.0                  2019-04-22
# 7010   2002        4.0                  2019-04-24
# 7011   1992        2.0                  2019-04-26
# 7012   2012        3.0                  2019-04-24
# 7013   2014        3.0                  2019-04-24
# 7014   1993        4.0                  2019-04-22
# 7015   2015        4.0                  2019-04-24
# 7016   2014        4.0                  2019-04-30
# 7017   1993        3.0                  2019-04-24
# 7018   1990        3.0                  2019-04-30
# 7019   1975        3.0                  2018-04-08
# 7020   2015        3.0                  2018-06-18
# 7021   1979        3.0                  2018-04-05
# 7022   1980        4.0                  2018-04-08
# 7023   1984        3.0                  2018-04-04
# 7024   2005        4.0                  2018-03-23
# 7025   2005        4.0                  2018-03-24
# 7026   2006        4.0                  2018-03-24
# 7027   2009        4.0                  2018-03-27
# 7028   1999        3.0                  2018-03-26
# 7029   2002        3.0                  2018-03-27
# 7030   2009        4.0                  2018-03-27
# 7031   2002        4.0                  2018-03-27
# 7032   2007        4.0                  2018-03-26
# 7033   2009        4.0                  2018-03-26
# 7034   1999        3.0                  2018-03-26
# 7036   2009        4.0                  2018-04-03
# 7037   2009        4.0                  2018-03-30
# 7038   2009        4.0                  2018-03-26
# 7049   2005        3.0                  2019-04-25
# 7052   2013        3.0                  2019-04-30
# 7053   1992        3.0                  2019-04-25
# 7065   2004        4.0                  2018-03-30
# 7066   1991        4.0                  2019-04-24
# 7067   2007        3.0                  2019-04-30
# 7068   1993        2.0                  2019-04-22
# 7069   2010        4.0                  2019-03-11
# 7070   2004        4.0                  2019-04-25
# 7071   1992        3.0                  2019-04-25
# 7072   2009       NaN                   NaT
# 7073   1975       NaN                   NaT
# 7074   2002       NaN                   NaT
# 8908   2012       NaN                   NaT
# 8913   2005       NaN                   NaT
# 8914   1999       NaN                   NaT
# 8915   2002       NaN                   NaT
# 8916   2009       NaN                   NaT
# 8917   2005       NaN                   NaT
# 8922   2007       NaN                   NaT
# 9693   2003        3.0                  2018-10-25
# 9694   1998        2.0                  2018-10-25
# 9854   2011        4.0                  2016-12-31
# 9856   1993        3.0                  2016-12-31
# 10461  1992        4.0                  2019-06-30
# 10462  2016        5.0                  2019-06-30
# 10468  1987        4.0                  2019-06-30
# 10694  1943        4.0                  2015-12-11
# 10695  1972        4.0                  2015-12-29
# 10696  2008        4.0                  2015-11-30
# 10712  2017        5.0                  2019-06-30
# 10713  1990        4.0                  2015-11-18
# 10731  1969        4.0                  2019-06-30
# 10734  1950        3.0                  2015-12-08
# 10735  1914        3.0                  2015-12-09
# 10736  1912        3.0                  2015-11-19
# 10737  1978        3.0                  2015-12-01
# 12334  2014        4.0                  2018-06-30
# 12549  2000       NaN                   NaT
# 12842  1975        3.0                  2019-09-30
# 12935  1975        4.0                  2018-04-20
#
#                                                                                                                                                                                                                                                                                                                                                                                                                Notes
# 0      Administrative offices, call & dispatch center, Operations & Maintenance facility; 2017 condition assessment score = 5
# 421    MB & CB share this facility.  Condition assessment (2019) performed by IT Facilities Manager.
# 425    Original agreement between IT and WSDOT began 10/24, 1983.  Site was expanded per cooperative agreement dated 10/13, 2008.  Condition assessment (2019) performed by IT Facilities Manager.
# 2714   No Data in 20 Year Needs. Was not part of the 20 year needs report so no condition assessment was done.
# 5700   I changed the condition assessment in error. The last assessment performed rated the facility a 2 and that remains the same until the next assessment is performed.
# 6263    Est. date of condition assessment 8/25/2018.
# 6264   Est. date of condition assessment 08/02/2018
# 6265   Est. date of condition assessment 07/23/2018
# 6266   Est. date of condition assessment 08/16/2018
# 6267    The station has a Bus Terminal for MBA.                                                              Est. date of condition assessment 08/23/2018.
# 6274   The station has a Bus Terminal for MBA.                                                              Est. date of condition assessment 08/23/2018.
# 6275   Est. date of condition assessment 08/02/2018.
# 6698   This facility is for assessment and training for people with disabilities.
# 6943   Condition assessment was performed by CR-BPS on 06/14/2018.
# 6944   The condition assessment of this facility and others 13477, 13521 and 16931 were estimated last year.  The final report from consultant last December 2019 confirm condition of these facilities are 4 instead of 3.\nCR-BPS performed condition assessment
# 6945   CR-BPS performed condition assessment.\nCoon Rapids/Riverdale P&R\nis including here as 1 passenger facility. To be consistent with A-10
# 6946   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for heavy rail passengers. This commuter rail station has parking garage and  parking lot.  \nCondition assessment was done by CR-BPS on 03/30/2018
# 6947   This facility type is described as Passenger and Parking Facilities per TAM guidelines. Condition assessment was done by CR-BPS on 04/03/2018 - phase 1.
# 6948   The condition assessment of this facility and others 13477, 13521 and 16931 were estimated last year.  The final report from consultant last December 2019 confirm condition of these facilities are 4 instead of 3.\nElk River Station (171st Ave & Tyler St) surface parking lot is included here as 1 passenger facility to be consistent with A-10 form\nCR-BPS performed condition assessment - phase 2.
# 6949   The condition assessment of this facility and others 13477, 13521 and 16931 were estimated last year.  The final report from consultant last December 2019 confirm condition of these facilities are 4 instead of 3.\nCR-BPS performed condition assessment. Phase 2.
# 6950   The condition assessment of this facility and others 13477, 13521 and 16931 were estimated last year.  The final report from consultant last December 2019 confirm condition of these facilities are 4 instead of 3.\n\nThis CR platform includes tunnel.\n\nCR-BPS performed condition assessment. Phase 2.
# 6951   Coon Rapid platform, skyway and Coon Rapids/Riverdale Station are together.  Coon Rapid platform and skyway section is reported together as CR station and Coon Rapids/Riverdale Station section is report as CR surface parking lot.\nCR-BPS performed condition assessment-phase 2.
# 6952   Elk River (171st Ave & Tyler St) Station and Elk River Station park and ride are together.  Elk River (171st Ave & Tyler St) Station section is reported as commuter rail platform and  Elk River station park and ride section is report as CR surface parking lot.\nCR-BPS performed condition assessment - phase 2.
# 6953   Fridley commuter rail site has rail platform, tunnel and parking lot.  Rail platform and tunnel are assess and report together and Fridley parking lot section is reported as surface parking lot.\nCR-BPS performed condition assessment - phase 2.
# 6954   Condition assessment was performed by CR-PBS on 06/11/2018.
# 6956   CR-BPS performed condition assessment. Phase 2
# 6957   CR-BPS performed condition assessment. Phase 1
# 6958   CR-BPS performed condition assessment. Phase 1.
# 6959   CR-BPS performed condition assessment. Phase 1.
# 6960   CR-BPS performed condition assessment. Phase 2.
# 6961   CR-BPS performed condition assessment. Phase 2.
# 6962   CR-BPS performed condition assessment. Phase 2.
# 6963   CR-BPS performed condition assessment. Phase 2.
# 6964   CR-BPS performed condition assessment. Phase 2.
# 6965   Remove Fort Snelling Station North and South surface parking lots and merge it here as 1 passenger facility to match with A-10 report.\nCR-BPS performed condition assessment. Phase 1.\nCondition assessment completed on 07/19/2018
# 6966   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for light rail passengers. Condition assessment was done by CR-BPS on 03/28/2018. Phase 1.
# 6967   CR-BPS performed condition assessment. Phase 2.
# 6968   CR-BPS performed condition assessment. Phase 2.
# 6969   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for light rail passengers. Condition assessment was done by CR-BPS on 03/29/2018. Phase 1.
# 6970   CR-BPS performed condition assessment. Phase 2.
# 6971   CR-BPS performed condition assessment. Phase 2.
# 6972   CR-BPS performed condition assessment. Phase 2.
# 6973   CR-BPS performed condition assessment. Phase 2.
# 6974   CR-BPS performed condition assessment. Phase 2.
# 6975   CR-BPS performed condition assessment. Phase 2.
# 6976   CR-BPS performed condition assessment. Phase 1.
# 6977   CR-BPS performed condition assessment. Phase 2.
# 6978   CR-BPS performed condition assessment. Phase 2.
# 6979   CR-BPS performed condition assessment. Phase 2.
# 6980   CR-BPS performed condition assessment. Phase 2.
# 6981   This facility type is described as Administration and Maintenance Facilities per TAM guidelines. Condition assessment was done by CR-BPS on 03/31/2018 - phase 1.
# 6982   Condition assessment was done by CR-BPS on 07/19/2018 - phase 1.
# 6983   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for light rail and bus passengers. Condition assessment was done by CR-BPS on 07/19/2018 - phase 1.\n\nThis is not only a Rail station but also a bus transfer center.
# 6984   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for light rail passengers. Condition assessment was done by CR-BPS on 07/19/2018 - phase 1.
# 6985   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for light rail passengers. Condition assessment was done and finalized by CR-BPS on 07/19/2018 - phase 1.
# 6986   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for light rail passengers. Condition assessment was done and finalized by CR-BPS on 07/19/2018 - phase 1.
# 6987   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for light rail passengers. Condition assessment was done by CR-BPS on 03/29/2018 - phase 1.
# 6988   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for light rail passengers. Condition assessment was done by CR-BPS on 03/28/2018 phase 1.\nThis is also a bus transfer center.
# 6989   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for light rail passengers. Condition assessment was done by CR-BPS on 03/29/2018 phase 1.
# 6990   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for light rail passengers. Condition assessment was done by CR-BPS on 03/29/2018 - phase 1.
# 6991   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for light rail passengers. Condition assessment was done by CR-BPS on 03/28/2018 - phase 1.
# 6992   CR-BPS performed condition assessment on 03/30/2018 and final report on 11/16/2018. Phase 1.
# 6993   CR-BPS performed condition assessment. Phase 2.
# 6994   CR-BPS performed condition assessment - phase 2.
# ...
# 7053   CR-BPS performed condition assessment. Phase 2.
# 7065   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is a Park & Ride. Condition assessment was done by CR-BPS on 03/30/2018 - phase 1.\nThis also calls South Bloomington Transit Center.
# 7066   CR-BPS performed condition assessment. Phase 2.
# 7067   This was build for the A line. It has restroom.\nCR-BPS performed condition assessment phase 2.
# 7068   CR-BPS performed condition assessment - phase 2.
# 7069   Big Lake station has rail platform and surface parking lot park and ride.  This is surface parking lot park and ride.\nCR-BPS performed condition assessment - phase 2.
# 7070   CR-BPS performed condition assessment - phase 2
# 7071   CR-BPS performed condition assessment. Phase 2.
# 7072   This is drivers building at Knox Ave at Best Buy. This facility has not been performed condition assessment yet.  Therefore, information reported here are estimated.
# 7073   This facility has not been performed condition assessment yet.  Therefore, information reported here are estimated.
# 7074   This facility has not been performed condition assessment yet.  Therefore, information reported here are estimated.
# 8908   Condition assessment was completed by CR-BPS on 06/14/2018.
# 8913   This facility type is described as Passenger and Parking Facilities per TAM guidelines. It is a transit centers. Condition assessment was done by CR-BPS on 03/24/2018
# 8914   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for bus passengers. Condition assessment was done by CR-BPS on 03/26/2018
# 8915   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for bus passengers. Condition assessment was done by CR-BPS on 03/27/2018
# 8916   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for bus passengers. Condition assessment was done by CR-BPS on 03/27/2018
# 8917   This facility type is described as Passenger and Parking Facilities per TAM guidelines.  It is used for light rail passengers. Condition assessment was done by CR-BPS on 03/28/2018.\nThis is also a bus transfer center.
# 8922   This was build for the A line. It has restroom.\nCR-BPS performed condition assessment phase 2.
# 9693   Date in assessment performed box is not accurate; facility was assessed on 2018-10-25 as NCRTD was not aware of the facility assessment requirements prior to the end of the fiscal year.
# 9694   Building is used for vehicle and equipment storage as well as minor/light maintenance tasks such as headlight changes.\n\nDate in assessment performed box is not accurate; facility was assessed on 2018-10-25 as NCRTD was not aware of the facility assessment requirements prior to the end of the fiscal year.
# 9854   Paratransit administration, operations, and maintenance. Condition assessment is actually 3.9
# 9856   Transit information center and bus transfer facility. Condition assessment is actually 3.2.
# 10461  Condition assessment 8/07/2019 on a yearly schedule
# 10462  Operations building \n4.6 Condition assessment performed on 7/30/2019
# 10468  3.7 Condition assessment performed on 7/25/2019
# 10694  Annex built 1984\n"Good" overall assessment = 4
# 10695  "Good" overall assessment = 4
# 10696  "Good" overall assessment = 4
# 10712  Further construction completed in FY19 "Excellent" overall assessment = 5
# 10713  "Good" overall assessment = 4
# 10731  Rennovations completed in FY19; update assessment to "Good" overall assessment = 4
# 10734  137 bus parking\n"Fair" overall assessment = 3
# 10735  "Fair" overall assessment = 3
# 10736  "Fair" overall assessment = 3
# 10737  "Fair" overall assessment = 3
# 12334  This facility was paid for using Connect Oregon funding not federal funding.  This is a transit center and is not a maintenance facility.\nThe condition assessment date has be corrected.
# 12549  N/A was selected - no condition assessment was completed in FY2019
# 12842  condition assessment 3\nBuilding is primarily for storage and some admin for dispatch and training.  The entire building is 30,424 sq ft with only 9,479 being used for transit.
# 12935  Condition assessment conducted by TranSystems (consultant) for ARDOT Statewide TAM Plan.  Inspected annually by ARDOT Staff Inspectors.\n\nYear Built: 1975; Addition Completed: 2009.

# %% [markdown]
# ## Performing the (Imperfect) Comparison

# %% [markdown]
# Scanning through some of the notes above, it looks like the reported values in Year Built are very accurate compared to the notes. At this point, it isn't clear whether it is valuable to actually extract the year from the notes column to perform a logical comparison.

# %%
pattern = '([0-9]{4})'

Notes_year['result'] = Notes_year.loc[:,'Notes'].str.extract(pattern)
Notes_year['result']=pd.to_numeric(Notes_year['result'])
Notes_year
# Out:
# /Users/Joe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Joe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                                             Agency Name  Year Built  \
# 166                           Spokane Transit Authority        2015
# 425                                   Intercity Transit        1983
# 478                                    County of Pierce        1983
# 942          Massachusetts Bay Transportation Authority        1900
# 945          Massachusetts Bay Transportation Authority        1900
# ...                                                 ...         ...
# 13038  Developmental Services of Northwest Kansas, Inc.        2005
# 13143                                 Town of Telluride        2013
# 13144                                 Town of Telluride        1987
# 13145                                 Town of Telluride        1999
# 13296                     Lassen Transit Service Agency        2001
#
#       Condition Assessment Date  \
# 166                  2017-04-28
# 425                  2020-02-14
# 478                  2019-04-24
# 942                  2019-06-29
# 945                  2019-06-29
# ...                         ...
# 13038                2018-06-30
# 13143                2018-08-15
# 13144                2018-08-15
# 13145                2018-08-15
# 13296                2018-06-30
#
#                                                    Notes  result
# 166    1212 Sharp is a administrative offices. Major ...    1212
# 425    Original agreement between IT and WSDOT began ...    1983
# 478                               47.178324, -122.677895    1783
# 942                 Permanent Admin Facility  built 1898    1898
# 945              Tower - Unoccupied/Abandoned Built 1875    1875
# ...                                                  ...     ...
# 13038  combination of admin space (2963 sf) and maint...    2963
# 13143  Facility type is hybrid Administrative and Mai...    2013
# 13144  Facility type is hybrid Administrative and Mai...    1987
# 13145  Facility type is hybrid Administrative and Mai...    1999
# 13296  Lassen Rural Bus Office and Maintenance Bay.  ...    1987
#
# [200 rows x 5 columns]

# %% [markdown]
# So I can use an equivalence operator to add a new column, 'agree', which is a true/false value indicating whether the years are the same across the two fields.

# %%
Notes_year['agree']=(Notes_year['result']==Notes_year['Year Built'])
Notes_year.value_counts('agree')
# Out:
# /Users/Joe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# agree
# False    161
# True      39
# dtype: int64

# %% [markdown]
# I can see from the above that there are only 39 results that agree. This seems like too many based on what I saw before. Upon further investigation I find out there must be a constraint in the system limiting the Year Built to 1900 and afterwards. So I adjust for that below.

# %%
Notes_year[Notes_year['result']>1900].value_counts('agree')
# Out:
# agree
# False    52
# True     38
# dtype: int64

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Now we see a much more balanced dataset. Let's check this set to make sure this is worthwhile.

# %%
(Notes_year[Notes_year['result']>1900][Notes_year['result']<2021][Notes_year['agree']==False])
# Out:
# /Users/Joe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /Users/Joe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                                                 Agency Name  \
# 1757   Pioneer Valley Transit Authority
# 1787   Housatonic Area Regional Transit
# 1789   Cape Ann Transportation Authority
# 1915   Connecticut Department of Transportation
# 1917   Connecticut Department of Transportation
# 1939   Connecticut Department of Transportation
# 1944   Connecticut Department of Transportation
# 2035   Niagara Frontier Transportation Authority
# 2036   Niagara Frontier Transportation Authority
# 2042   Niagara Frontier Transportation Authority
# 2043   Niagara Frontier Transportation Authority
# 2849   Metro-North Commuter Railroad Company, dba: MTA Metro-North Railroad
# 2851   Metro-North Commuter Railroad Company, dba: MTA Metro-North Railroad
# 2873   Metro-North Commuter Railroad Company, dba: MTA Metro-North Railroad
# 2878   Metro-North Commuter Railroad Company, dba: MTA Metro-North Railroad
# 3287   New York City Department of Transportation
# 5596   South Central Transit Authority
# 5597   South Central Transit Authority
# 5692   City of High Point
# 6037   County of Miami-Dade
# 6052   County of Miami-Dade
# 6453   Lake County Board of County Commissioners
# 6579   Autonomous Municipality of Ponce
# 6765   The Greater Cleveland Regional Transit Authority
# 6786   The Greater Cleveland Regional Transit Authority
# 6791   The Greater Cleveland Regional Transit Authority
# 6792   The Greater Cleveland Regional Transit Authority
# 6925   Portage Area Regional Transportation Authority
# 7133   City of Niles
# 7430   Chicago Transit Authority
# 7431   Chicago Transit Authority
# 7716   Laketran
# 9020   City of Amarillo
# 9239   VIA Metropolitan Transit
# 9257   VIA Metropolitan Transit
# 9585   City of Tyler
# 10694  City and County of San Francisco
# 11266  City of Simi Valley
# 11267  City of Simi Valley
# 12026  The Eastern Contra Costa Transit Authority
# 12192  Carson Area Metropolitan Planning Organization
# 12329  Grant County Transportation District
# 12819  Gogebic County Transit
# 12847  Rainbow Rider Transit Board
# 12851  Isanti County
# 12862  Cedar Valley Services, Inc.
# 12880  Faribault-Martin Counties Joint Powers
# 13296  Lassen Transit Service Agency
#
#        Year Built Condition Assessment Date  \
# 1757   1985       2018-06-30
# 1787   1998       2019-07-30
# 1789   2001       2018-06-30
# 1915   1986       NaT
# 1917   1991       NaT
# 1939   1992       NaT
# 1944   1996       NaT
# 2035   2003       2017-01-01
# 2036   2003       2017-01-01
# 2042   2016       2017-01-01
# 2043   2016       2017-01-01
# 2849   1986       NaT
# 2851   1991       NaT
# 2873   1992       NaT
# 2878   1996       NaT
# 3287   2005       2018-06-29
# 5596   2013       2018-06-30
# 5597   2010       2018-06-30
# 5692   2008       2019-06-30
# 6037   2015       2019-08-05
# 6052   2013       2019-06-19
# 6453   2013       2018-09-12
# 6579   1987       NaT
# 6765   1996       2019-06-01
# 6786   2016       2019-06-01
# 6791   1999       2019-06-01
# 6792   2001       2019-06-01
# 6925   2003       2018-08-14
# 7133   2018       2019-12-19
# 7430   1966       2018-12-31
# 7431   1930       2018-12-31
# 7716   1992       2018-12-31
# 9020   1981       2018-09-01
# 9239   1940       2015-07-01
# 9257   1987       2015-07-01
# 9585   2002       2018-06-20
# 10694  1943       2015-12-11
# 11266  2012       2019-06-30
# 11267  2012       2019-06-30
# 12026  2004       2018-03-28
# 12192  2018       2018-06-28
# 12329  2016       2017-06-30
# 12819  1996       2018-08-01
# 12847  2010       2019-05-01
# 12851  2007       2018-10-25
# 12862  2010       2019-04-04
# 12880  2005       2019-04-03
# 13296  2001       2018-06-30
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Notes  \
# 1757   \nThe University of Massachusetts owned the original building. Since UMTS became a contractor to PVTA in 1974, PVTA has made many rehabilitation's to the building in order to operate public transit out of the building. The value of the rehabilitated dollars of the building is 50% of the value of the entire building.
# 1787   Administrative Office and Maintenance Facility. The building was constructed in 1986 and renovated in 1998. The building is a two story structure with a large bus storage area.
# 1789   built in 1980, CATA purchased 2001 and rehabbed 2001-2004; building houses a small administration area, operations/dispatch, and maintenance.  All vehicles are housed and maintained inside the building.
# 1915   Original Lot Built in 1977 - Town Owned
# 1917   Original Lot built in 1967 (Town Owned)
# 1939   Original Lot built in 1978 (Town Owned)
# 1944   Built in 1985 - State Owned
# 2035   Opened as Auditorium station Oct 9, 1984
# 2036   Opened as Auditorium station Oct 9, 1984
# 2042   Opened October 9, 1984 Rebuilt 7/5-21/14
# 2043   Opened October 9, 1984 Rebuilt 10/14/14
# 2849   Original Lot Built in 1977 - Town Owned
# 2851   Original Lot built in 1967 (Town Owned)
# 2873   Original Lot built in 1978 (Town Owned)
# 2878   Built in 1985 - State Owned
# 3287   The St. George Ferry Terminal located in Staten Island was constructed in 1948-50, with major remodeling and alterations undertaken between 2001-05.  The building is a structure incorporating a ferry terminal with four ferry slips and associated transfer bridges, waiting and circulation spaces, ferry operational, dispatch, crew, and ancillary spaces, a commuter rail station and rail yard, a roof top bus terminal, concession spaces, commuter parking and vehicle circulation structures, and ancillary buildings and structures, all situated on a 7 acre site. \n
# 5596   Restored original Reading Railroad train station originally built in 1929.  Currently not being used due to prior cutback in service.
# 5597   Originally built in 1979 and fully renovated and expanded in 2010.  Operations facility for both administrative and maintenance functions.
# 5692   The facility was originally constructed in 1979,  In 2008/2009 the administrative portion of the facility was remodeled.\n\nThe administrative offices take up approximately 4,500 square feet to include staff offices, restrooms, a training/conference room, and operator check-in area.\n\nThe maintenance area is in the remaining space.  The maintenance space includes a general work area plus 4 maintenance bays.
# 6037   Originally built 1994
# 6052   Originally built in 1994
# 6453   The building was built by the State of Florida Department of Highway Safety and Patrol in 1965.  Lake County BCC received the property in May 2012 and refurbished the building in 2013 with FTA funding.
# 6579   Since 1986, when the public transportation Terminal Carlos Garay, began to operate, the house beside the terminal became the administrative office of the terminal, function which currently holds. This office operates within an ancient structure that is part of the historic area of Ponce. This office is located between Victoria and Union Streets, and is part of Carlos Garay Terminal. It is considered as a historical value structure by the State Historical Preservation Office (SHPO). Since 2011 the municipality requested the opinion of SHPO for the rehabilitation process. After SHPO Office reviewed the documentation determined that the office is a historic property.\nThe original facade of the property dated from the years 1890 to 1900.
# 6765   Station serves LR ONLY.\nADA accessible 3 Elevators\nRoof replaced 2016\nFacility = 2040 sq ft\nPlatform 123x 10w=1230 x 2 (e/w) = 2460 sq ft. \nTotal Sq Ft= 4,500
# 6786   Station serves LR.\nADA accessible 2 Ramps 2018\nPlatform 1700x 10w=1700 x 2 (eb/wb) = 3,400 sq ft.\n
# 6791   Station serves LR.\nADA accessible 2 Ramps rebuilt 2019\nPlatform 120x 10w=1200 x 2 (eb/wb) = 2400 sq ft.\n
# 6792   Station serves LR.\nADA accessible 2018 rebuilt\nPlatform 150x 10w=1500 x 2 (eb/wb) = 3000 sq ft.\n
# 6925   The facility was originally built in 1983. The administrative offices were added on in 2003. In the garage, fire suppression was upgrade and a new roof added in 2010. And part of the garage was renovated in 2018 to be CNG compliant.  I would consider the reconstructed as new date to be 2003.
# 7133   Niles DART is a small agency. Operations, administration, and maintenance are housed in one facility.    There is also a passenger waiting area in the front lobby of the building.  The building was purchased by the City of Niles in the early 1980's.  It has been renovated several times, most recently in 2018.
# 7430   Former Substation. Built in 1907, modernized in 1966
# 7431   Former substation. Decommissioned in 1973
# 7716   1998 Renovations\ndoubled garage size\n2005 Renovations\nincreased dispatch size
# 9020   The offices, bus barn, and maintenance shop are all connected in one facility.  The latest remodel was in 2016-2017 (new office additions, not completely reconstructed as new).  1981 was the year this facility was built.
# 9239   Orginally built 1907 as international and Great Northern Depot.  Significant but not total renovation in 2010.\nThis building is used by our senior leadership to establish policy and address issues related to both bus and paratransit service.
# 9257   Original building 1948; major renovation 1987 to add 4 lanes; 2004 added 2 lanes
# 9585   Originally built in 1905
# 10694  Annex built 1984\n"Good" overall assessment = 4
# 11266  The administrative offices were originally constructed in 1989, and were remodeled in 2012.  The remodel included expansion and reconfiguration of the offices, and installation of a new HVAC system.
# 11267  The maintenance garage was constructed in 1989, and was remodeled in 2012.  The remodel included installing a brake adjustment pit, parts room,  and bringing the facility into ADA compliance by installing new north and west doors and an ADA compliant parts counter.
# 12026  The original combined administrative and maintenance Facility was constructed in 1986. It was expanded in 2004.
# 12192  Admin facility was relocated 6.26.18. Although the building was constructed in 1985, was fully remodeled in 2018 to like new condition.
# 12329  Facility houses administrative office, passenger transfer, buses bay areas. No maintenance such as oil changes occur here.\nBuilt 1938, Rebuild in 1991, remodel 2016.\n
# 12819  admin 1,324 sq ft, dispatch 300 sq ft.\nmaintenance 1944 sq ft\nstorage 2,322 sq ft\nIntermodal ticket office 144 sq ft
# 12847  Overnight Storage.  Built in 1990, remodeled in 2010.
# 12851  Office Staff in Office Area, Maintenance (Service and Inspection) completed in Maintenance Area and Overnight Storage.  Original Building built in 1972, Transit Acquired and reconstructed in 2007.
# 12862  Overnight Storage in Garage Area.  Original building built in 1965, Transit purchased and reconstructed in 2010.
# 12880  Overnight Storage only.  Original building built in 1973 and 1977, Transit Purchased and remodeled in 2005.
# 13296  Lassen Rural Bus Office and Maintenance Bay.  Built 1987; rebuilt 2001
#
#        result  agree
# 1757   1974    False
# 1787   1986    False
# 1789   1980    False
# 1915   1977    False
# 1917   1967    False
# 1939   1978    False
# 1944   1985    False
# 2035   1984    False
# 2036   1984    False
# 2042   1984    False
# 2043   1984    False
# 2849   1977    False
# 2851   1967    False
# 2873   1978    False
# 2878   1985    False
# 3287   1948    False
# 5596   1929    False
# 5597   1979    False
# 5692   1979    False
# 6037   1994    False
# 6052   1994    False
# 6453   1965    False
# 6579   1986    False
# 6765   2016    False
# 6786   2018    False
# 6791   2019    False
# 6792   2018    False
# 6925   1983    False
# 7133   1980    False
# 7430   1907    False
# 7431   1973    False
# 7716   1998    False
# 9020   2016    False
# 9239   1907    False
# 9257   1948    False
# 9585   1905    False
# 10694  1984    False
# 11266  1989    False
# 11267  1989    False
# 12026  1986    False
# 12192  1985    False
# 12329  1938    False
# 12819  1944    False
# 12847  1990    False
# 12851  1972    False
# 12862  1965    False
# 12880  1973    False
# 13296  1987    False

# %% [markdown]
# There are many values in this set that seem worth pursuing. Some are false positives as there were multiple values in the notes and the second one was right, where my query only captured the first one.
#
# What I would like to do in the future is go back and select the highest first, since "Year Built" is also defined as "Year Remodeled as New". In other words, the value captured from the notes may be describing the original year built, which would not be reported.
