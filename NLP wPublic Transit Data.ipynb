# %% [markdown]
# # Extracting and Comparing Year Transit Facility Rebuilt From Notes

# %% [markdown]
# ## Loading in Data

# %% [markdown]
# In this exercise I will need the regex (re) package, pandas, and natural language toolkit.

# %%
import re
import pandas as pd
import nltk

# %% [markdown]
# I am pulling in a published dataset that my team would like to work with. Each record holds data on a single transit agency facility, reported as of 2019.

# %%
response='https://www.transit.dot.gov/sites/fta.dot.gov/files/2020-10/2019%20Facility%20Inventory.xlsx'
response
df=pd.read_excel(response)

# %% [markdown]
# There is a column for Year Built, as well as when a condition assessment was performed, and any notes that the reporting transit agency felt were relevant to include. I only care about these particular records (along with the name of the agency) and I only care about records that have notes provided.

# %%
al=df[['Agency Name','Year Built','Condition Assessment Date','Notes']]
Notes_only=al[al.Notes.notnull()] #filtering out all non-null notes
Notes_only
# Out:
#                                    Agency Name  Year Built  \
# 0      King County Department of Metro Transit        2017
# 5      King County Department of Metro Transit        2011
# 9      King County Department of Metro Transit        1980
# 12     King County Department of Metro Transit        2014
# 13     King County Department of Metro Transit        2014
# ...                                        ...         ...
# 13305     County of Hawaii Mass Transit Agency        2018
# 13306                          Humboldt County        2016
# 13308              Pahrump Senior Center, Inc.        1960
# 13315                       City of El Segundo        2008
# 13317                               Mt Clemens        2017
#
#       Condition Assessment Date  \
# 0                           NaT
# 5                    2015-01-01
# 9                    2015-01-01
# 12                   2015-01-01
# 13                   2015-01-01
# ...                         ...
# 13305                2018-06-30
# 13306                2017-02-10
# 13308                2018-09-30
# 13315                2018-10-01
# 13317                2018-03-28
#
#                                                    Notes
# 0      Administrative offices, call & dispatch center...
# 5                                    Operations Building
# 9                                       Hostler building
# 12          Maintenance emergency spill response storage
# 13                        Maintenance tire chain storage
# ...                                                  ...
# 13305  Facility includes a 110'x150' Maintenance Area...
# 13306  Senior center, Admin, Passenger parking, and v...
# 13308  Pahrump Senior Center, parking, passenger load...
# 13315  This facility was built by El Segundo, the lan...
# 13317                BUS GARAGE/DISPATCH/SUPVSR OFFICE\n
#
# [6474 rows x 4 columns]

# %% [markdown]
# ## Using Natural Language Processing to Extract Year

# %% [markdown]
# Now I will use regular expression (regex) tokenization to find the right string. I want to find a four digit year, which can be in either the 1900s or the 2000s. The first command below will limit the Notes_Year

# %%
Notes_year=Notes_only[Notes_only['Notes'].str.contains('1[0-9]{3}','20[0-9]{2}')] #497 have rows that are probably years
Notes_year['Notes']
# Out:
# 166      1212 Sharp is a administrative offices. Major ...
# 425      Original agreement between IT and WSDOT began ...
# 478                                 47.178324, -122.677895
# 942                   Permanent Admin Facility  built 1898
# 945                Tower - Unoccupied/Abandoned Built 1875
#                                ...
# 13038    combination of admin space (2963 sf) and maint...
# 13143    Facility type is hybrid Administrative and Mai...
# 13144    Facility type is hybrid Administrative and Mai...
# 13145    Facility type is hybrid Administrative and Mai...
# 13296    Lassen Rural Bus Office and Maintenance Bay.  ...
# Name: Notes, Length: 200, dtype: object

# %%
Notes_year.head(1)
# Out:
#                    Agency Name  Year Built Condition Assessment Date  \
# 166  Spokane Transit Authority        2015                2017-04-28
#
#                                                  Notes
# 166  1212 Sharp is a administrative offices. Major ...

# %% [markdown]
# This does not not show the entire notes field (is truncated). I'd like to quickly verify that they all have years, to verify my code above worked. I can use the option context function to display the max column width using the following.

# %%
with pd.option_context('display.max_colwidth', -1): display(Notes_year) #https://stackoverflow.com/questions/25351968/how-to-display-full-non-truncated-dataframe-information-in-html-when-convertin
# Out:
#                                             Agency Name  Year Built  \
# 166    Spokane Transit Authority                         2015
# 425    Intercity Transit                                 1983
# 478    County of Pierce                                  1983
# 942    Massachusetts Bay Transportation Authority        1900
# 945    Massachusetts Bay Transportation Authority        1900
# ...                                           ...         ...
# 13038  Developmental Services of Northwest Kansas, Inc.  2005
# 13143  Town of Telluride                                 2013
# 13144  Town of Telluride                                 1987
# 13145  Town of Telluride                                 1999
# 13296  Lassen Transit Service Agency                     2001
#
#       Condition Assessment Date  \
# 166   2017-04-28
# 425   2020-02-14
# 478   2019-04-24
# 942   2019-06-29
# 945   2019-06-29
# ...          ...
# 13038 2018-06-30
# 13143 2018-08-15
# 13144 2018-08-15
# 13145 2018-08-15
# 13296 2018-06-30
#
#                                                                                                                                                                                              Notes
# 166    1212 Sharp is a administrative offices. Major remodel in 2015.
# 425    Original agreement between IT and WSDOT began 10/24, 1983.  Site was expanded per cooperative agreement dated 10/13, 2008.  Condition assessment (2019) performed by IT Facilities Manager.
# 478    47.178324, -122.677895
# 942    Permanent Admin Facility  built 1898
# 945    Tower - Unoccupied/Abandoned Built 1875
# ...                                        ...
# 13038  combination of admin space (2963 sf) and maint (14353 sf)
# 13143  Facility type is hybrid Administrative and Maintenance; phase 3 was in 2013. Phase 2 was in 1999 . Phase 1 was 1987
# 13144  Facility type is hybrid Administrative and Maintenance; originally built in 1987
# 13145  Facility type is hybrid Administrative and Maintenance; Phase 2 was in 1999
# 13296  Lassen Rural Bus Office and Maintenance Bay.  Built 1987; rebuilt 2001
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Performing the (Imperfect) Comparison

# %% [markdown]
# Scanning through some of the notes above, it looks like the reported values in Year Built are very accurate compared to the notes. At this point, it isn't clear whether it is valuable to actually extract the year from the notes column to perform a logical comparison.

# %%
pattern = '([0-9]{4})'

Notes_year['result'] = Notes_year.loc[:,'Notes'].str.extract(pattern)
Notes_year['result']=to_numeric(Notes_year['result'])
Notes_year
# Out:
# /Users/Joe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Joe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                                             Agency Name  Year Built  \
# 166                           Spokane Transit Authority        2015
# 425                                   Intercity Transit        1983
# 478                                    County of Pierce        1983
# 942          Massachusetts Bay Transportation Authority        1900
# 945          Massachusetts Bay Transportation Authority        1900
# ...                                                 ...         ...
# 13038  Developmental Services of Northwest Kansas, Inc.        2005
# 13143                                 Town of Telluride        2013
# 13144                                 Town of Telluride        1987
# 13145                                 Town of Telluride        1999
# 13296                     Lassen Transit Service Agency        2001
#
#       Condition Assessment Date  \
# 166                  2017-04-28
# 425                  2020-02-14
# 478                  2019-04-24
# 942                  2019-06-29
# 945                  2019-06-29
# ...                         ...
# 13038                2018-06-30
# 13143                2018-08-15
# 13144                2018-08-15
# 13145                2018-08-15
# 13296                2018-06-30
#
#                                                    Notes  result  flagged  \
# 166    1212 Sharp is a administrative offices. Major ...    1212    False
# 425    Original agreement between IT and WSDOT began ...    1983     True
# 478                               47.178324, -122.677895    1783    False
# 942                 Permanent Admin Facility  built 1898    1898    False
# 945              Tower - Unoccupied/Abandoned Built 1875    1875    False
# ...                                                  ...     ...      ...
# 13038  combination of admin space (2963 sf) and maint...    2963    False
# 13143  Facility type is hybrid Administrative and Mai...    2013     True
# 13144  Facility type is hybrid Administrative and Mai...    1987     True
# 13145  Facility type is hybrid Administrative and Mai...    1999     True
# 13296  Lassen Rural Bus Office and Maintenance Bay.  ...    1987    False
#
#           ok  agree
# 166    False  False
# 425     True   True
# 478    False  False
# 942    False  False
# 945    False  False
# ...      ...    ...
# 13038  False  False
# 13143   True   True
# 13144   True   True
# 13145   True   True
# 13296  False  False
#
# [200 rows x 8 columns]

# %% [markdown]
# So I can use an equivalence operator to add a new column, 'agree', which is based on true/false.

# %%
Notes_year['agree']=(Notes_year['result']==Notes_year['Year Built'])
Notes_year.value_counts('agree')
# Out:
# /Users/Joe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# agree
# False    161
# True      39
# dtype: int64

# %% [markdown]
# I can see from the above that there are only 39 results that agree. This seems like too many based on what I saw before. Upon further investigation I find out there must be a constraint in the system limiting the Year Built to 1900 and afterwards.

# %%
Notes_year[Notes_year['result']>1900].value_counts('agree')
# Out:
# agree
# False    52
# True     38
# dtype: int64

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Now we see a much more balanced dataset. Let's check this set to make sure this is worthwhile.

# %%
Notes_year[Notes_year['result']>1900][Notes_year['result']<2021][Notes_year['agree']==False]
# Out:
# /Users/Joe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /Users/Joe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                              Agency Name  Year Built  \
# 1757                    Pioneer Valley Transit Authority        1985
# 1787                   Housatonic Area Regional Transit         1998
# 1789                   Cape Ann Transportation Authority        2001
# 1915            Connecticut Department of Transportation        1986
# 1917            Connecticut Department of Transportation        1991
# 1939            Connecticut Department of Transportation        1992
# 1944            Connecticut Department of Transportation        1996
# 2035           Niagara Frontier Transportation Authority        2003
# 2036           Niagara Frontier Transportation Authority        2003
# 2042           Niagara Frontier Transportation Authority        2016
# 2043           Niagara Frontier Transportation Authority        2016
# 2849   Metro-North Commuter Railroad Company, dba: MT...        1986
# 2851   Metro-North Commuter Railroad Company, dba: MT...        1991
# 2873   Metro-North Commuter Railroad Company, dba: MT...        1992
# 2878   Metro-North Commuter Railroad Company, dba: MT...        1996
# 3287          New York City Department of Transportation        2005
# 5596                     South Central Transit Authority        2013
# 5597                     South Central Transit Authority        2010
# 5692                                  City of High Point        2008
# 6037                               County of Miami-Dade         2015
# 6052                               County of Miami-Dade         2013
# 6453           Lake County Board of County Commissioners        2013
# 6579                    Autonomous Municipality of Ponce        1987
# 6765    The Greater Cleveland Regional Transit Authority        1996
# 6786    The Greater Cleveland Regional Transit Authority        2016
# 6791    The Greater Cleveland Regional Transit Authority        1999
# 6792    The Greater Cleveland Regional Transit Authority        2001
# 6925      Portage Area Regional Transportation Authority        2003
# 7133                                      City of Niles         2018
# 7430                           Chicago Transit Authority        1966
# 7431                           Chicago Transit Authority        1930
# 7716                                            Laketran        1992
# 9020                                    City of Amarillo        1981
# 9239                            VIA Metropolitan Transit        1940
# 9257                            VIA Metropolitan Transit        1987
# 9585                                       City of Tyler        2002
# 10694                   City and County of San Francisco        1943
# 11266                                City of Simi Valley        2012
# 11267                                City of Simi Valley        2012
# 12026         The Eastern Contra Costa Transit Authority        2004
# 12192     Carson Area Metropolitan Planning Organization        2018
# 12329               Grant County Transportation District        2016
# 12819                             Gogebic County Transit        1996
# 12847                        Rainbow Rider Transit Board        2010
# 12851                                      Isanti County        2007
# 12862                        Cedar Valley Services, Inc.        2010
# 12880             Faribault-Martin Counties Joint Powers        2005
# 13296                      Lassen Transit Service Agency        2001
#
#       Condition Assessment Date  \
# 1757                 2018-06-30
# 1787                 2019-07-30
# 1789                 2018-06-30
# 1915                        NaT
# 1917                        NaT
# 1939                        NaT
# 1944                        NaT
# 2035                 2017-01-01
# 2036                 2017-01-01
# 2042                 2017-01-01
# 2043                 2017-01-01
# 2849                        NaT
# 2851                        NaT
# 2873                        NaT
# 2878                        NaT
# 3287                 2018-06-29
# 5596                 2018-06-30
# 5597                 2018-06-30
# 5692                 2019-06-30
# 6037                 2019-08-05
# 6052                 2019-06-19
# 6453                 2018-09-12
# 6579                        NaT
# 6765                 2019-06-01
# 6786                 2019-06-01
# 6791                 2019-06-01
# 6792                 2019-06-01
# 6925                 2018-08-14
# 7133                 2019-12-19
# 7430                 2018-12-31
# 7431                 2018-12-31
# 7716                 2018-12-31
# 9020                 2018-09-01
# 9239                 2015-07-01
# 9257                 2015-07-01
# 9585                 2018-06-20
# 10694                2015-12-11
# 11266                2019-06-30
# 11267                2019-06-30
# 12026                2018-03-28
# 12192                2018-06-28
# 12329                2017-06-30
# 12819                2018-08-01
# 12847                2019-05-01
# 12851                2018-10-25
# 12862                2019-04-04
# 12880                2019-04-03
# 13296                2018-06-30
#
#                                                    Notes  result  flagged  \
# 1757   \nThe University of Massachusetts owned the or...    1974    False
# 1787   Administrative Office and Maintenance Facility...    1986    False
# 1789   built in 1980, CATA purchased 2001 and rehabbe...    1980    False
# 1915             Original Lot Built in 1977 - Town Owned    1977    False
# 1917             Original Lot built in 1967 (Town Owned)    1967    False
# 1939             Original Lot built in 1978 (Town Owned)    1978    False
# 1944                         Built in 1985 - State Owned    1985    False
# 2035            Opened as Auditorium station Oct 9, 1984    1984    False
# 2036            Opened as Auditorium station Oct 9, 1984    1984    False
# 2042            Opened October 9, 1984 Rebuilt 7/5-21/14    1984    False
# 2043             Opened October 9, 1984 Rebuilt 10/14/14    1984    False
# 2849             Original Lot Built in 1977 - Town Owned    1977    False
# 2851             Original Lot built in 1967 (Town Owned)    1967    False
# 2873             Original Lot built in 1978 (Town Owned)    1978    False
# 2878                         Built in 1985 - State Owned    1985    False
# 3287   The St. George Ferry Terminal located in State...    1948    False
# 5596   Restored original Reading Railroad train stati...    1929    False
# 5597   Originally built in 1979 and fully renovated a...    1979    False
# 5692   The facility was originally constructed in 197...    1979    False
# 6037                               Originally built 1994    1994    False
# 6052                            Originally built in 1994    1994    False
# 6453   The building was built by the State of Florida...    1965    False
# 6579   Since 1986, when the public transportation Ter...    1986    False
# 6765   Station serves LR ONLY.\nADA accessible 3 Elev...    2016    False
# 6786   Station serves LR.\nADA accessible 2 Ramps 201...    2018    False
# 6791   Station serves LR.\nADA accessible 2 Ramps reb...    2019    False
# 6792   Station serves LR.\nADA accessible 2018 rebuil...    2018    False
# 6925   The facility was originally built in 1983. The...    1983    False
# 7133   Niles DART is a small agency. Operations, admi...    1980    False
# 7430   Former Substation. Built in 1907, modernized i...    1907    False
# 7431           Former substation. Decommissioned in 1973    1973    False
# 7716   1998 Renovations\ndoubled garage size\n2005 Re...    1998    False
# 9020   The offices, bus barn, and maintenance shop ar...    2016    False
# 9239   Orginally built 1907 as international and Grea...    1907    False
# 9257   Original building 1948; major renovation 1987 ...    1948    False
# 9585                            Originally built in 1905    1905    False
# 10694    Annex built 1984\n"Good" overall assessment = 4    1984    False
# 11266  The administrative offices were originally con...    1989    False
# 11267  The maintenance garage was constructed in 1989...    1989    False
# 12026  The original combined administrative and maint...    1986    False
# 12192  Admin facility was relocated 6.26.18. Although...    1985    False
# 12329  Facility houses administrative office, passeng...    1938    False
# 12819  admin 1,324 sq ft, dispatch 300 sq ft.\nmainte...    1944    False
# 12847  Overnight Storage.  Built in 1990, remodeled i...    1990    False
# 12851  Office Staff in Office Area, Maintenance (Serv...    1972    False
# 12862  Overnight Storage in Garage Area.  Original bu...    1965    False
# 12880  Overnight Storage only.  Original building bui...    1973    False
# 13296  Lassen Rural Bus Office and Maintenance Bay.  ...    1987    False
#
#           ok  agree
# 1757   False  False
# 1787   False  False
# 1789   False  False
# 1915   False  False
# 1917   False  False
# 1939   False  False
# 1944   False  False
# 2035   False  False
# 2036   False  False
# 2042   False  False
# 2043   False  False
# 2849   False  False
# 2851   False  False
# 2873   False  False
# 2878   False  False
# 3287   False  False
# 5596   False  False
# 5597   False  False
# 5692   False  False
# 6037   False  False
# 6052   False  False
# 6453   False  False
# 6579   False  False
# 6765   False  False
# 6786   False  False
# 6791   False  False
# 6792   False  False
# 6925   False  False
# 7133   False  False
# 7430   False  False
# 7431   False  False
# 7716   False  False
# 9020   False  False
# 9239   False  False
# 9257   False  False
# 9585   False  False
# 10694  False  False
# 11266  False  False
# 11267  False  False
# 12026  False  False
# 12192  False  False
# 12329  False  False
# 12819  False  False
# 12847  False  False
# 12851  False  False
# 12862  False  False
# 12880  False  False
# 13296  False  False

# %% [markdown]
# There are many values in this set that seem worth pursuing. Some are false positives as there were multiple values in the notes and the second one was right, where my query only captured the first one. What I would like to do in the future is go back and select the highest first, since "Year Built" is also defined as "Year Remodeled as New". In other words, the notes may be describing the original year built, which would not be reported.
